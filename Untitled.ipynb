# %%
pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 106.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 16.8 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.5-py3-none-any.whl size=138634 sha256=d3dbedea7b1d072f2ef567f3e82aedf0488d96752c08a11903cb30dd9ec37e22
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/f7/47/5a/f60cfd4dd60dad2a4f66a9fabe98dc0b97d82f7112846dbb21
# Successfully built peewee
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
tesla_data = yf.download('TSLA', start='2020-01-01', end='2024-01-01', interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tesla_data.reset_index(inplace=True)

# %%
tesla_data.to_csv('tesla_stock_data.csv', index=False)

# %%
print(tesla_data.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 1 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 3 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 4 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %%
import pandas as pd

# Data extracted from Macrotrends
data = {
    'Date': ['2024-03-31', '2023-12-31', '2023-09-30', '2023-06-30', '2023-03-31', '2022-12-31', '2022-09-30', '2022-06-30', '2022-03-31'],
    'Revenue (Millions of US $)': [21301, 25167, 23350, 24927, 23329, 24318, 21454, 16934, 18756]
}

# Creating DataFrame
tesla_revenue = pd.DataFrame(data)

# %%
print(tesla_revenue.tail())
# Out:
#          Date  Revenue (Millions of US $)
# 4  2023-03-31                       23329
# 5  2022-12-31                       24318
# 6  2022-09-30                       21454
# 7  2022-06-30                       16934
# 8  2022-03-31                       18756

# %%
gme_data = yf.download('GME', start='2020-01-01', end='2024-01-01', interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
gme_data.reset_index(inplace=True)

# %%
gme_data.to_csv('gme_stock_data.csv', index=False)

# %%
print(gme_data.head())
# Out:
#         Date    Open    High     Low   Close  Adj Close    Volume
# 0 2020-01-02  1.5350  1.6175  1.5175  1.5775     1.5775  17814400
# 1 2020-01-03  1.5525  1.5625  1.4600  1.4700     1.4700  14175600
# 2 2020-01-06  1.4500  1.4775  1.4000  1.4625     1.4625  13579200
# 3 2020-01-07  1.4425  1.4575  1.3600  1.3800     1.3800  20912000
# 4 2020-01-08  1.3725  1.4625  1.3525  1.4300     1.4300  22517600

# %%
import pandas as pd

# Data extracted from Macrotrends
data = {
    'Date': ['2024-04-30', '2024-01-31', '2023-10-31', '2023-07-31', '2023-04-30', '2023-01-31'],
    'Revenue (Millions of US $)': [882, 1794, 1078, 1164, 1237, 2226]
}

# Creating DataFrame
gme_revenue = pd.DataFrame(data)

# %%
print(gme_revenue.tail())
# Out:
#          Date  Revenue (Millions of US $)
# 1  2024-01-31                        1794
# 2  2023-10-31                        1078
# 3  2023-07-31                        1164
# 4  2023-04-30                        1237
# 5  2023-01-31                        2226

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
tesla_data = pd.read_csv('tesla_stock_data.csv')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure(figsize=(10, 5))
plt.plot(tesla_data['Date'], tesla_data['Close'], label='Closing Price')
plt.title('Tesla Stock Closing Prices')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
gme_data = pd.read_csv('gme_stock_data.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(gme_data['Date'], gme_data['Close'], label='Closing Price', color='green')
plt.title('GameStop Stock Closing Prices')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()
